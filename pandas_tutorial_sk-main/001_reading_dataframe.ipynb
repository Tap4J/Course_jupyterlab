# %% [markdown]
# # Základy práce s dataframe
# Dataframe je základný datový typ pri práci s knižnicou pandas. V tomto videu si ukážeme základnú prácu s Dataframe.
#
# Link na [video](https://youtu.be/YFkMFO3BbRI)

# %%
import pandas as pd

# %%
# Nacitanie dat
# sep = oddelovanie hodnot
# names = nazvy stlpcov
# skiprows = kolko riadkov sa ma vynechat pri citani
df_train = pd.read_csv("dataset/train.csv", 
#                        index_col="Id",
#                        sep=",",
#                        names=list(range(0,81)),
#                        skiprows=10
                      )
df_test = pd.read_csv("dataset/test.csv")

# %%
# shape vrati rozmery df (pocet riadkov, pocet stlpcov)
df_train.shape
# Out:
# (1460, 81)

# %%
# axes vrati osi dataframu [os indexu, os stlpcov]
df_train.axes
# Out:
# [RangeIndex(start=0, stop=1460, step=1),
#  Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#         'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#         'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#         'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#         'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#         'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#         'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#         'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#         'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#         'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#         'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#         'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %% [markdown]
# Vsimnime si ze kedze sme nespecifikovali stplec pre index python pouzil vlastny index RangeIndex

# %%
df_train
# Out:
#         10  190  RL    50   7420  Pave   NA  Reg  Lvl  AllPub  ... 0.10 NA.1  \
# 0       11   20  RL  70.0  11200  Pave  NaN  Reg  Lvl  AllPub  ...    0  NaN
# 1       12   60  RL  85.0  11924  Pave  NaN  IR1  Lvl  AllPub  ...    0  NaN
# 2       13   20  RL   NaN  12968  Pave  NaN  IR2  Lvl  AllPub  ...    0  NaN
# 3       14   20  RL  91.0  10652  Pave  NaN  IR1  Lvl  AllPub  ...    0  NaN
# 4       15   20  RL   NaN  10920  Pave  NaN  IR1  Lvl  AllPub  ...    0  NaN
# ...    ...  ...  ..   ...    ...   ...  ...  ...  ...     ...  ...  ...  ...
# 1445  1456   60  RL  62.0   7917  Pave  NaN  Reg  Lvl  AllPub  ...    0  NaN
# 1446  1457   20  RL  85.0  13175  Pave  NaN  Reg  Lvl  AllPub  ...    0  NaN
# 1447  1458   70  RL  66.0   9042  Pave  NaN  Reg  Lvl  AllPub  ...    0  NaN
# 1448  1459   20  RL  68.0   9717  Pave  NaN  Reg  Lvl  AllPub  ...    0  NaN
# 1449  1460   20  RL  75.0   9937  Pave  NaN  Reg  Lvl  AllPub  ...    0  NaN
#
# ...
